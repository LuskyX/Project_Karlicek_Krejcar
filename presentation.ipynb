# %% [markdown]
# # Finding nearest vaccination centers
#
# Based on arguments given by user (more below) our program find 3 nearest vaccination centers.
#
# For this purpose we are scraping https://ockoreport.uzis.cz/ for obtaining data about centers.
# This data we are merging with dataset from https://onemocneni-aktualne.mzcr.cz/api/v2/covid-19
# where we get gps coordinates of vaccination centers
#
# Also, we are scraping wikipedia to obtain gps coordinates of locations in Czech Republic.
#
# All data are then stored in SQLlite3 database.
#
#
# ## Arguments
#
# * `location`
#     * name of town / village in Czech Republic or name of part of Prague
#     * for options see:
#         * https://cs.wikipedia.org/wiki/Seznam_obc%C3%AD_v_%C4%8Cesku
#         * https://cs.wikipedia.org/wiki/Praha#%C3%9Azemn%C3%AD_%C4%8Dlen%C4%9Bn%C3%AD
#     * if some town is duplicit you need to specify region also:
#         * format: "name (region)"
#         * example: "Kozojedy (okres Plzeň-sever)"
#
# * `vaccine`
#     * specify desired vaccine, if None the vaccine won't be taken into account
#     * default None
#     * options: COMIRNATY, SPIKEVAX, JANSSEN, Vaxzevria, None
#
# * `age_group`
#     * specify your age group, default to "adult"
#     * options:
#         * adult: 18+
#         * teenage: 16-17
#         * child: 12-15
#
# * `without_registration`
#     * default None = you don't if you will go to center with registration or not
#     * if True = you only want centers without registration
#     * if False = you only want centers with registration
#
# * `self_payer`
#     * default False = you are not self-payer
#     * if True = you want only centers for self-payers
#
# * `monday`
#     * specify your desired time on Monday, default None
#     * accept int or float, thus for "10:30" set monday = 10.5
#
# * `tuesday`, `wednesday`, `thursday`, `friday`, `saturday`, `sunday`
#     * same as monday
#     * if you specify more days, the program will find centers with opening hours which will meet conditions for atleast 1 day
#     * if all days are None then opening hours will not be taken into account
#
# * `update`
#     * default to False = does nothing
#     * if True = it downloads data and update database
#
#
# ## Update
#
# For update set `update=True`. It should take around 70 minutes.
#
#
# ## How to run
# Just open the **presentation.ipynb** and run `give_me_three_centers` from `main.py` with your specific arguments.

# %%
from main import give_me_three_centers

# %%
centers = give_me_three_centers(location='Kozojedy (okres Plzeň-sever)')
# Out:
# ____________________________________________________________________________________________________
# Name: 	 EUC Klinika, Na Palcátech 352, Kralovice
# Link: 	 https://ockoreport.uzis.cz/Detail?guid=a0b3a397-29de-4207-bc36-402c3e2fb78e
# ID:   	 a0b3a397-29de-4207-bc36-402c3e2fb78e
#
# Region:     Plzeňský
# Address:    Na Palcátech 352, 331 41 Kralovice
#             Lidový dům
#
# Phone:      +420601102712
# Email:      ockovani.plzen@eucklinika.cz
#
# Note: Linka 1221 nemá oprávnění měnit termíny očkování.
#
# Vaccines:       JANSSEN/Johnson&Johnson (osoby starší 18 let), COMIRNATY/Pfizer, SPIKEVAX/Moderna
# Center type:    Osoby starší 18 let, Osoby ve věku 16-17 let
# Daily capacity: 400
# Change of date: Telefonicky - očkovací místo +420601102712, Emailem - očkovací místo ockovani.plzen@eucklinika.cz
#
# Opening hours:
# _________________________________
#                Open    |  Closed
# Monday:       | None   |  None  |
# Tuesday:      | None   |  None  |
# Wednesday:    | None   |  None  |
# Thursday:     | 08:30  |  16:30 |
# Friday:       | None   |  None  |
# Saturday:     | None   |  None  |
# Sunday:       | None   |  None  |
# ____________________________________________________________________________________________________
#
#
# ____________________________________________________________________________________________________
# Name: 	 Rokycanská nemocnice, Voldušská 750, Nové Město, Rokycany
# Link: 	 https://ockoreport.uzis.cz/Detail?guid=333a11ee-363d-499f-90cb-9d61f62543cc
# ID:   	 333a11ee-363d-499f-90cb-9d61f62543cc
#
# Region:     Plzeňský
# Address:    Voldušská 750, Nové Město, 337 01 Rokycany
#             V hlavní budově, přízemí, vedle příjmových ambulancí
#
# Phone:      724320397
# Email:      hana.perkova@rokycany.nemocnicepk.cz
#
# Note:
#
# Vaccines:       COMIRNATY/Pfizer
# Center type:    Bezbariérový přístup, Osoby starší 18 let
# Daily capacity: 250
# Change of date: Telefonicky - linka 1221
#
# Opening hours:
# _________________________________
#                Open    |  Closed
# Monday:       | 07:00  |  15:00 |
# Tuesday:      | 07:00  |  15:00 |
# Wednesday:    | 07:00  |  15:00 |
# Thursday:     | 07:00  |  15:00 |
# Friday:       | 07:00  |  15:00 |
# Saturday:     | 07:00  |  15:00 |
# Sunday:       | 07:00  |  15:00 |
# ____________________________________________________________________________________________________
#
#
# ____________________________________________________________________________________________________
# Name: 	 (Bez registrace) Privamed, Kotíkovská 927/19, 323 00 Plzeň 1-Severní Předměstí
# Link: 	 https://ockoreport.uzis.cz/Detail?guid=c6c0cf40-1c36-478a-9523-ba8c9382af50
# ID:   	 c6c0cf40-1c36-478a-9523-ba8c9382af50
#
# Region:     Plzeňský
# Address:    Kotíkovská 927/19, 323 00 Plzeň 1-Severní Předměstí
#
#
# Phone:
# Email:
#
# Note:
#
# Vaccines:       COMIRNATY/Pfizer
# Center type:    Osoby starší 18 let, Očkovací místo bez předchozí registrace a rezervace
# Daily capacity: 500
# Change of date:
#
# Opening hours:
# _________________________________
#                Open    |  Closed
# Monday:       | 08:00  |  14:00 |
# Tuesday:      | None   |  None  |
# Wednesday:    | None   |  None  |
# Thursday:     | None   |  None  |
# Friday:       | None   |  None  |
# Saturday:     | None   |  None  |
# Sunday:       | None   |  None  |
# ____________________________________________________________________________________________________
