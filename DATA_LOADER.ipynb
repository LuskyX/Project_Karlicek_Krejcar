# %% [markdown]
# # DATA LOADER

# %%
import pandas as pd

# %%
data = pd.read_csv('https://onemocneni-aktualne.mzcr.cz/api/v2/covid-19/ockovani.csv')

# %%
data.tail(50)
# Out:
#             datum    vakcina kraj_nuts_kod            kraj_nazev  \
# 48005  2021-05-13  VAXZEVRIA         CZ063         Kraj Vysočina
# 48006  2021-05-13  VAXZEVRIA         CZ064     Jihomoravský kraj
# 48007  2021-05-13  VAXZEVRIA         CZ064     Jihomoravský kraj
# 48008  2021-05-13  VAXZEVRIA         CZ064     Jihomoravský kraj
# 48009  2021-05-13  VAXZEVRIA         CZ064     Jihomoravský kraj
# 48010  2021-05-13  VAXZEVRIA         CZ064     Jihomoravský kraj
# 48011  2021-05-13  VAXZEVRIA         CZ064     Jihomoravský kraj
# 48012  2021-05-13  VAXZEVRIA         CZ064     Jihomoravský kraj
# 48013  2021-05-13  VAXZEVRIA         CZ064     Jihomoravský kraj
# 48014  2021-05-13  VAXZEVRIA         CZ064     Jihomoravský kraj
# 48015  2021-05-13  VAXZEVRIA         CZ064     Jihomoravský kraj
# 48016  2021-05-13  VAXZEVRIA         CZ064     Jihomoravský kraj
# 48017  2021-05-13  VAXZEVRIA         CZ064     Jihomoravský kraj
# ...
